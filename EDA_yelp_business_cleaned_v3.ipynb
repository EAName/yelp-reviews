# %% [markdown]
# <a href="https://colab.research.google.com/github/EAName/yelp-reviews/blob/main/EDA_yelp_business_cleaned_v3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
from tqdm import tqdm

import json
import os

import pandas as pd
import numpy as np
import matplotlib
from matplotlib import pyplot as plt
import seaborn as sns
import statistics
import numpy as np

# %matplotlib inline

# %%
# First drop yelp_dataset into your drive (Add shortcut to Drive)
business_json_path = '/content/gdrive/MyDrive/yelp_dataset/yelp_business_clean_version1.csv'
df_b = pd.read_csv(business_json_path)
# Out:
# /usr/local/lib/python3.7/dist-packages/IPython/core/interactiveshell.py:3326: DtypeWarning: Columns (43,44,45,46) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
df_b
# Out:
#        Unnamed: 0             business_id                           name  \
# 0               8  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 1              12  il_Ro8jwPlHresjw9EGmBg                        Denny's
# 2              15  MUTTqe8uqyMdBl186RmNeA                       Tuna Bar
# 3              19  ROeacJQwBeh05Rqg7F6TCg                            BAP
# 4              22  kfNv-JZpuN6TVNSO6hHdkw                Hibachi Express
# ...           ...                     ...                            ...
# 35285      150298  gPr1io7ks0Eo3FDsnDTYfg                      Tata Cafe
# 35286      150306  wVxXRFf10zTTAs11nr4xeA                   PrimoHoagies
# 35287      150322  2MAQeAqmD8enCT2ZYqUgIQ    The Melting Pot - Nashville
# 35288      150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 35289      150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                     address          city state  postal_code   latitude  \
# ...

# %%
df_b.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35290 entries, 0 to 35289
# Data columns (total 68 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  35290 non-null  int64
#  1   business_id                 35290 non-null  object
#  2   name                        35290 non-null  object
#  3   address                     35215 non-null  object
#  4   city                        35290 non-null  object
#  5   state                       35290 non-null  object
#  6   postal_code                 35289 non-null  float64
#  7   latitude                    35290 non-null  float64
#  8   longitude                   35290 non-null  float64
#  9   stars                       35290 non-null  float64
#  10  review_count                35290 non-null  int64
#  11  is_open                     35290 non-null  int64
#  12  attributes                  34914 non-null  object
# ...

# %%
#Have ten features which are across all the restaurants

# %%
#AcceptsInsurance
#DietaryRestrictions
#ByAppointmentOnly
#BusinessAcceptsBitcoin
#GoodForMeal
#DogsAllowed
#RestaurantsTableService
#GoodForDancing
#CoatCheck
#BestNights
#DriveThru
#Open24Hours
#BYOB
#Corkage
#RestaurantsCounterService

# %%
df_columns_deleted = df_b.drop(columns = ['AcceptsInsurance','DietaryRestrictions','ByAppointmentOnly','BusinessAcceptsBitcoin','GoodForMeal','DogsAllowed','RestaurantsTableService','GoodForDancing','CoatCheck','BestNights','DriveThru','Open24Hours','BYOB','Corkage','RestaurantsCounterService'])

# %%
df_columns_deleted.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35290 entries, 0 to 35289
# Data columns (total 53 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Unnamed: 0                  35290 non-null  int64
#  1   business_id                 35290 non-null  object
#  2   name                        35290 non-null  object
#  3   address                     35215 non-null  object
#  4   city                        35290 non-null  object
#  5   state                       35290 non-null  object
#  6   postal_code                 35289 non-null  float64
#  7   latitude                    35290 non-null  float64
#  8   longitude                   35290 non-null  float64
#  9   stars                       35290 non-null  float64
#  10  review_count                35290 non-null  int64
#  11  is_open                     35290 non-null  int64
#  12  attributes                  34914 non-null  object
# ...

# %%
#Two-dimensional count for NaN values in the entire dataframe
df_columns_deleted.isnull().sum().sum()
# Out:
# 165783

# %%
#drop rows which contain more than 5 NaN values
df_droppedNaN = df_columns_deleted[df_columns_deleted.isnull().sum(axis=1) < 10]

# %%
df_droppedNaN.isnull().sum().sum()
# Out:
# 108993

# %%
df_droppedNaN.fillna(0)
# Out:
#        Unnamed: 0             business_id                           name  \
# 0               8  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 1              12  il_Ro8jwPlHresjw9EGmBg                        Denny's
# 2              15  MUTTqe8uqyMdBl186RmNeA                       Tuna Bar
# 3              19  ROeacJQwBeh05Rqg7F6TCg                            BAP
# 5              23  9OG5YkX1g2GReZM0AskizA        Romano's Macaroni Grill
# ...           ...                     ...                            ...
# 35285      150298  gPr1io7ks0Eo3FDsnDTYfg                      Tata Cafe
# 35286      150306  wVxXRFf10zTTAs11nr4xeA                   PrimoHoagies
# 35287      150322  2MAQeAqmD8enCT2ZYqUgIQ    The Melting Pot - Nashville
# 35288      150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 35289      150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                     address          city state  postal_code   latitude  \
# ...

# %%
df_droppedNaN.replace({False: 0, True: 1}, inplace=True)
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py:5244: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   method=method,

# %%
df_droppedNaN
# Out:
#        Unnamed: 0             business_id                           name  \
# 0               8  k0hlBqXX-Bt0vf1op7Jr1w          Tsevi's Pub And Grill
# 1              12  il_Ro8jwPlHresjw9EGmBg                        Denny's
# 2              15  MUTTqe8uqyMdBl186RmNeA                       Tuna Bar
# 3              19  ROeacJQwBeh05Rqg7F6TCg                            BAP
# 5              23  9OG5YkX1g2GReZM0AskizA        Romano's Macaroni Grill
# ...           ...                     ...                            ...
# 35285      150298  gPr1io7ks0Eo3FDsnDTYfg                      Tata Cafe
# 35286      150306  wVxXRFf10zTTAs11nr4xeA                   PrimoHoagies
# 35287      150322  2MAQeAqmD8enCT2ZYqUgIQ    The Melting Pot - Nashville
# 35288      150323  w_4xUt-1AyY2ZwKtnjW0Xg           Bittercreek Alehouse
# 35289      150336  WnT9NIzQgLlILjPT0kEcsQ  Adelita Taqueria & Restaurant
#
#                     address          city state  postal_code   latitude  \
# ...

# %%
df_droppedNaN.to_csv('/content/gdrive/MyDrive/yelp_dataset/yelp_business_clean_version2.csv')

# %%
#Regression model
#Y = b1x1 + b2x2...+
